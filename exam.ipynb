# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.shape
# Out:
# (395, 30)

# %%
df.size
# Out:
# 11850

# %%
df.drop(['school','sex','age'], axis = 1,inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.drop(['school','sex','age'], axis = 1,inplace = True)
#       2 df
#
# File C:\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
sns.histplot(df,kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['G1'])
# Out:
# <Axes: ylabel='G1'>

# %%
df.info
# Out:
# <bound method DataFrame.info of     address famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason guardian  \
# 0         U     GT3       A     4     4   at_home   teacher  course   mother
# 1         U     GT3       T     1     1   at_home     other  course   father
# 2         U     LE3       T     1     1   at_home     other   other   mother
# 3         U     GT3       T     4     2    health  services    home   mother
# 4         U     GT3       T     3     3     other     other    home   father
# ..      ...     ...     ...   ...   ...       ...       ...     ...      ...
# 390       U     LE3       A     2     2  services  services  course    other
# 391       U     LE3       T     3     1  services  services  course   mother
# 392       R     GT3       T     1     1     other     other  course    other
# 393       R     LE3       T     3     2  services     other  course   mother
# 394       U     LE3       T     1     1     other   at_home  course   father
#
# ...

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     address famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason guardian  \
# 0         U     GT3       A     4     4   at_home   teacher  course   mother
# 1         U     GT3       T     1     1   at_home     other  course   father
# 2         U     LE3       T     1     1   at_home     other   other   mother
# 3         U     GT3       T     4     2    health  services    home   mother
# 4         U     GT3       T     3     3     other     other    home   father
# ..      ...     ...     ...   ...   ...       ...       ...     ...      ...
# 390       U     LE3       A     2     2  services  services  course    other
# 391       U     LE3       T     3     1  services  services  course   mother
# 392       R     GT3       T     1     1     other     other  course    other
# 393       R     LE3       T     3     2  services     other  course   mother
# 394       U     LE3       T     1     1     other   at_home  course   father
#
# ...

# %%
df.columns
# Out:
# Index(['address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     address famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason guardian  \
# 0         U     GT3       A     4     4   at_home   teacher  course   mother
# 1         U     GT3       T     1     1   at_home     other  course   father
# 2         U     LE3       T     1     1   at_home     other   other   mother
# 3         U     GT3       T     4     2    health  services    home   mother
# 4         U     GT3       T     3     3     other     other    home   father
# ..      ...     ...     ...   ...   ...       ...       ...     ...      ...
# 390       U     LE3       A     2     2  services  services  course    other
# 391       U     LE3       T     3     1  services  services  course   mother
# 392       R     GT3       T     1     1     other     other  course    other
# 393       R     LE3       T     3     2  services     other  course   mother
# 394       U     LE3       T     1     1     other   at_home  course   father
#
# ...

# %%
df["famsize"].unique
# Out:
# <bound method Series.unique of 0      GT3
# 1      GT3
# 2      LE3
# 3      GT3
# 4      GT3
#       ...
# 390    LE3
# 391    LE3
# 392    GT3
# 393    LE3
# 394    LE3
# Name: famsize, Length: 395, dtype: object>

# %%
df["traveltime"].unique
# Out:
# <bound method Series.unique of 0      2
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 390    1
# 391    2
# 392    1
# 393    3
# 394    1
# Name: traveltime, Length: 395, dtype: int64>

# %%
a=sns.pairplot(df['studytime','freetime'])
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('studytime', 'freetime')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 a=sns.pairplot(df['studytime','freetime'])
#       2 a
#
# ...

# %%
df=pd.read_csv("student_data.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.drop(['romantic','famsup','famrel','traveltime','address','famsize'],axis=1, inplace=True)

# %%
df["school"].value_counts()
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %%
df.groupby("school")["sex"].count().sort_values(ascending=True)
# Out:
# school
# MS     46
# GP    349
# Name: sex, dtype: int64

# %%
df.groupby("sex")["school"].count().sort_values(ascending=True)
# Out:
# sex
# M    187
# F    208
# Name: school, dtype: int64
